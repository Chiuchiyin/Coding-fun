# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = 'data/trump_tweets.csv'
trump_tweets = pd.read_csv(data)

# %%
trump_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56571 entries, 0 to 56570
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          56571 non-null  float64
#  1   text        56571 non-null  object
#  2   is_retweet  56571 non-null  bool
#  3   is_deleted  56571 non-null  bool
#  4   device      56571 non-null  object
#  5   favorites   56571 non-null  int64
#  6   retweets    56571 non-null  int64
#  7   datetime    56571 non-null  object
#  8   is_flagged  56571 non-null  bool
#  9   date        56571 non-null  object
# dtypes: bool(3), float64(1), int64(2), object(4)
# memory usage: 3.2+ MB

# %%
trump_tweets.sort_values(by=['favorites'], ascending=False)
# Out:
#                  id                                               text  \
# 11759  1.311892e+18  Tonight, @FLOTUS and I tested positive for COV...
# 11807  1.312234e+18     Going welI, I think! Thank you to all. LOVE!!!
# 2559   1.325100e+18                     I WON THIS ELECTION, BY A LOT!
# 165    1.326159e+18                                       WE WILL WIN!
# 2565   1.325195e+18  71,000,000 Legal Votes. The most EVER for a si...
# ...             ...                                                ...
# 9432   1.295948e+18  RT @MrMichaelBurkes: Raise your hand if you'll...
# 9431   1.295948e+18  RT @MrMichaelBurkes: If you support President ...
# 9429   1.281450e+18  RT @ScottAdamsSays: Which side ignored this st...
# 9428   1.261116e+18  RT @DailyCaller: We got no response from the @...
# 25594  2.891202e+17                  @BradyMagic @EricTrump Thank you!
#
#        is_retweet  is_deleted              device  favorites  retweets  \
# 11759       False       False  Twitter for iPhone    1869706    408866
# 11807       False       False  Twitter for iPhone    1219870    139605
# 2559        False       False  Twitter for iPhone    1188311    190721
# 165         False       False  Twitter for iPhone    1023598    164891
# 2565        False       False  Twitter for iPhone     978022    157628
# ...           ...         ...                 ...        ...       ...
# 9432         True       False  Twitter for iPhone          0     21404
# 9431         True       False  Twitter for iPhone          0     15613
# 9429         True       False  Twitter for iPhone          0     12249
# 9428         True       False  Twitter for iPhone          0      7113
# 25594       False       False  Twitter Web Client          0         0
#
#                    datetime  is_flagged        date
# 11759  2020-10-02T04:54:06Z       False  2020-10-02
# 11807  2020-10-03T03:31:34Z       False  2020-10-03
# 2559   2020-11-07T15:36:36Z        True  2020-11-07
# 165    2020-11-10T13:44:22Z       False  2020-11-10
# 2565   2020-11-07T21:54:48Z       False  2020-11-07
# ...                     ...         ...         ...
# 9432   2020-08-19T04:57:43Z       False  2020-08-19
# 9431   2020-08-19T04:57:33Z       False  2020-08-19
# 9429   2020-07-10T04:46:05Z       False  2020-07-10
# 9428   2020-05-15T02:08:20Z       False  2020-05-15
# 25594  2013-01-09T21:23:29Z       False  2013-01-09
#
# [56571 rows x 10 columns]

# %%
display(trump_tweets.text.iloc[11759])
# Out:
# 'Tonight, @FLOTUS and I tested positive for COVID-19. We will begin our quarantine and recovery process immediately. We will get through this TOGETHER!'

# %%
trump_tweets.sort_values(by=['retweets'], ascending=False)
# Out:
#                  id                                               text  \
# 11759  1.311892e+18  Tonight, @FLOTUS and I tested positive for COV...
# 35620  8.815031e+17         #FraudNewsCNN #FNN https://t.co/WYUnHjjUjg
# 39347  7.959548e+17                 TODAY WE MAKE AMERICA GREAT AGAIN!
# 29598  4.741343e+17  Are you allowed to impeach a president for gro...
# 9080   1.267638e+18       RT @SpaceX: Liftoff! https://t.co/DRBfdUM7JA
# ...             ...                                                ...
# 25181  2.962780e+17                               @SandyInu We'll see.
# 25537  2.894816e+17                           @LaDaleBuggs  Thank you.
# 25182  2.962771e+17  @Cletendre21 @LetendreLarry But not hard enoug...
# 25536  2.894818e+17                 @MStuart1970 @foxandfriends  True!
# 25316  2.938158e+17                    @adkradio Thanks and good luck.
#
#        is_retweet  is_deleted               device  favorites  retweets  \
# 11759       False       False   Twitter for iPhone    1869706    408866
# 35620       False       False   Twitter for iPhone     503063    293109
# 39347       False       False  Twitter for Android     498035    281289
# 29598       False       False  Twitter for Android     231077    237674
# 9080         True       False   Twitter for iPhone          0    235250
# ...           ...         ...                  ...        ...       ...
# 25181       False       False   Twitter Web Client          0         0
# 25537       False       False   Twitter Web Client          0         0
# 25182       False       False   Twitter Web Client          0         0
# 25536       False       False   Twitter Web Client          0         0
# 25316       False       False   Twitter Web Client          0         0
#
#                    datetime  is_flagged        date
# 11759  2020-10-02T04:54:06Z       False  2020-10-02
# 35620  2017-07-02T13:21:42Z       False  2017-07-02
# 39347  2016-11-08T11:43:14Z       False  2016-11-08
# 29598  2014-06-04T10:23:11Z       False  2014-06-04
# 9080   2020-06-02T02:02:10Z       False  2020-06-02
# ...                     ...         ...         ...
# 25181  2013-01-29T15:26:03Z       False  2013-01-29
# 25537  2013-01-10T21:19:18Z       False  2013-01-10
# 25182  2013-01-29T15:22:31Z       False  2013-01-29
# 25536  2013-01-10T21:20:16Z       False  2013-01-10
# 25316  2013-01-22T20:22:01Z       False  2013-01-22
#
# [56571 rows x 10 columns]

# %%
display(trump_tweets.text.iloc[29598])
# Out:
# 'Are you allowed to impeach a president for gross incompetence?'
